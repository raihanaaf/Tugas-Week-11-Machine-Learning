# %% [markdown]
# # Heart Dataset
#
# **Raihana Fawaz (1103210102)**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
# Memuat dataset
df = pd.read_csv('heart.csv')

df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# Praproses Data: Pisahkan fitur dan target
X = df.drop('target', axis=1).values
y = df['target'].values

# %%
# Normalisasi data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Mengonversi data ke dalam bentuk tensor
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# %%
# Membuat model MLP
def create_mlp(input_size, hidden_layers, hidden_neurons, activation_function):
    layers = []
    # Lapisan input ke lapisan tersembunyi pertama
    layers.append(nn.Linear(input_size, hidden_neurons))

    # Menambahkan lapisan tersembunyi tambahan
    for _ in range(hidden_layers - 1):
        layers.append(nn.Linear(hidden_neurons, hidden_neurons))

    # Memilih fungsi aktivasi
    if activation_function == 'linear':
        activation = nn.Identity()
    elif activation_function == 'Sigmoid':
        activation = nn.Sigmoid()
    elif activation_function == 'ReLU':
        activation = nn.ReLU()
    elif activation_function == 'Softmax':
        activation = nn.Softmax(dim=1)
    elif activation_function == 'Tanh':
        activation = nn.Tanh()

    # Menambahkan lapisan output
    layers.append(nn.Linear(hidden_neurons, 2))  # Menghasilkan 2 kelas (0 atau 1)
# Membuat model MLP
def create_mlp(input_size, hidden_layers, hidden_neurons, activation_function):
    layers = []
    # Lapisan input ke lapisan tersembunyi pertama
    layers.append(nn.Linear(input_size, hidden_neurons))

    # Menambahkan lapisan tersembunyi tambahan
    for _ in range(hidden_layers - 1):
        layers.append(nn.Linear(hidden_neurons, hidden_neurons))

    # Memilih fungsi aktivasi
    if activation_function == 'linear':
        activation = nn.Identity()
    elif activation_function == 'Sigmoid':
        activation = nn.Sigmoid()
    elif activation_function == 'ReLU':
        activation = nn.ReLU()
    elif activation_function == 'Softmax':
        activation = nn.Softmax(dim=1)
    elif activation_function == 'Tanh':
        activation = nn.Tanh()

    # Menambahkan lapisan output
    layers.append(nn.Linear(hidden_neurons, 2))  # Menghasilkan 2 kelas (0 atau 1)

    # Menggabungkan semua lapisan menjadi satu model
    model = nn.Sequential(*layers)
    return model

# %%
# Fungsi untuk melatih dan mengevaluasi model
def train_and_evaluate(model, X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, batch_size, epochs, learning_rate):
    # DataLoader untuk pelatihan dalam batch
    train_data = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)

    # Optimizer (Adam) dan fungsi loss (CrossEntropyLoss untuk klasifikasi)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    # Loop pelatihan
    model.train()  # Mengatur model ke mode pelatihan
    for epoch in range(epochs):
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()  # Mengatur ulang gradien
            output = model(X_batch)  # Melakukan prediksi dengan model
            loss = criterion(output, y_batch)  # Menghitung nilai loss
            loss.backward()  # Melakukan backpropagation
            optimizer.step()  # Memperbarui parameter model

    # Evaluasi model setelah pelatihan
    model.eval()  # Mengatur model ke mode evaluasi (tanpa pembaruan gradien)
    with torch.no_grad():  # Menonaktifkan perhitungan gradien untuk efisiensi
        # Akurasi pelatihan
        train_output = model(X_train_tensor)
        train_pred = torch.argmax(train_output, dim=1)  # Prediksi kelas menggunakan argmax
        train_accuracy = accuracy_score(y_train_tensor.numpy(), train_pred.numpy())  # Menghitung akurasi pelatihan
        train_loss = criterion(train_output, y_train_tensor).item()  # Menghitung loss pada data pelatihan

        # Akurasi pengujian
        test_output = model(X_test_tensor)
        test_pred = torch.argmax(test_output, dim=1)
        test_accuracy = accuracy_score(y_test_tensor.numpy(), test_pred.numpy())  # Menghitung akurasi pengujian
        test_loss = criterion(test_output, y_test_tensor).item()  # Menghitung loss pada data pengujian

    return train_accuracy, train_loss, test_accuracy, test_loss  # Mengembalikan hasil

# %%
# Daftar hyperparameter untuk eksperimen
hidden_layers_options = [1, 2, 3]  # Jumlah lapisan tersembunyi
hidden_neurons_options = [8, 16, 32]  # Jumlah neuron di setiap lapisan tersembunyi
activation_functions = ['linear', 'Sigmoid', 'ReLU', 'Softmax', 'Tanh']  # Fungsi aktivasi yang digunakan
epochs_options = [10, 25, 50, 100]  # Jumlah epoch pelatihan
learning_rates = [0.1, 0.01, 0.001, 0.0001]  # Tingkat pembelajaran
batch_sizes = [64, 128, 256, 512]  # Ukuran batch data

# Melakukan eksperimen dengan semua kombinasi hyperparameter
results = []  # Menyimpan hasil eksperimen
best_result = None
worst_result = None

for hidden_layers in hidden_layers_options:
    for hidden_neurons in hidden_neurons_options:
        for activation_function in activation_functions:
            for epochs in epochs_options:
                for learning_rate in learning_rates:
                    for batch_size in batch_sizes:
                        # Mencetak konfigurasi hyperparameter yang sedang digunakan
                        print(f"Melatih dengan {hidden_layers} lapisan tersembunyi, {hidden_neurons} neuron, fungsi aktivasi {activation_function}, "
                              f"{epochs} epoch, tingkat pembelajaran {learning_rate}, ukuran batch {batch_size}")

                        # Membuat model dengan kombinasi hyperparameter tertentu
                        model = create_mlp(X_train_tensor.shape[1], hidden_layers, hidden_neurons, activation_function)

                        # Melatih dan mengevaluasi model
                        train_acc, train_loss, test_acc, test_loss = train_and_evaluate(
                            model, X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, batch_size, epochs, learning_rate
                        )

                        # Menyimpan hasil eksperimen
                        results.append({
                            'Hidden Layers': hidden_layers,
                            'Hidden Neurons': hidden_neurons,
                            'Activation Function': activation_function,
                            'Epochs': epochs,
                            'Learning Rate': learning_rate,
                            'Batch Size': batch_size,
                            'Train Accuracy': train_acc,
                            'Train Loss': train_loss,
                            'Test Accuracy': test_acc,
                            'Test Loss': test_loss
                        })

                        # Mencetak hasil akhir dari eksperimen saat ini
                        print(f"Akurasi Pelatihan: {train_acc * 100:.2f}%")
                        print(f"Loss Pelatihan: {train_loss:.4f}")
                        print(f"Akurasi Pengujian: {test_acc * 100:.2f}%")
                        print(f"Loss Pengujian: {test_loss:.4f}\n")

                        # Memperbarui hasil terbaik dan terburuk
                        if best_result is None or test_acc > best_result['Test Accuracy']:
                            best_result = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }
                        if worst_result is None or test_acc < worst_result['Test Accuracy']:
                            worst_result = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }
# Out:
# Streaming output truncated to the last 5000 lines.
# Loss Pengujian: 0.6381
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Sigmoid, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 65.97%
# Loss Pelatihan: 0.6207
# Akurasi Pengujian: 64.61%
# Loss Pengujian: 0.6163
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 85.22%
# Loss Pelatihan: 0.3720
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.4054
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3403
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4287
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.19%
# Loss Pelatihan: 0.3394
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4536
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 84.38%
# Loss Pelatihan: 0.3462
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4066
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3363
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4213
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3340
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4160
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 84.80%
# Loss Pelatihan: 0.3393
# Akurasi Pengujian: 78.25%
# Loss Pengujian: 0.4031
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.05%
# Loss Pelatihan: 0.3574
# Akurasi Pengujian: 78.57%
# Loss Pengujian: 0.4331
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 84.52%
# Loss Pelatihan: 0.3525
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4081
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 80.33%
# Loss Pelatihan: 0.4660
# Akurasi Pengujian: 75.00%
# Loss Pengujian: 0.4876
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 77.68%
# Loss Pelatihan: 0.5794
# Akurasi Pengujian: 76.62%
# Loss Pengujian: 0.5774
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 57.18%
# Loss Pelatihan: 0.6770
# Akurasi Pengujian: 54.55%
# Loss Pengujian: 0.6848
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 50.91%
# Loss Pelatihan: 0.6762
# Akurasi Pengujian: 53.57%
# Loss Pengujian: 0.6622
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 49.37%
# Loss Pelatihan: 0.6962
# Akurasi Pengujian: 48.70%
# Loss Pengujian: 0.6955
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 54.25%
# Loss Pelatihan: 0.6893
# Akurasi Pengujian: 52.60%
# Loss Pengujian: 0.6878
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.7512
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.7826
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 84.38%
# Loss Pelatihan: 0.3569
# Akurasi Pengujian: 78.57%
# Loss Pengujian: 0.4288
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3357
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.4145
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 87.17%
# Loss Pelatihan: 0.3362
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.4193
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3430
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4497
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3342
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.4137
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4194
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3338
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4171
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 85.50%
# Loss Pelatihan: 0.3359
# Akurasi Pengujian: 78.25%
# Loss Pengujian: 0.4143
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 85.91%
# Loss Pelatihan: 0.3351
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4188
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 84.94%
# Loss Pelatihan: 0.3413
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4096
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 77.13%
# Loss Pelatihan: 0.5034
# Akurasi Pengujian: 75.65%
# Loss Pengujian: 0.5141
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.7388
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.7139
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 79.50%
# Loss Pelatihan: 0.5931
# Akurasi Pengujian: 73.70%
# Loss Pengujian: 0.6026
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.7280
# Akurasi Pengujian: 52.60%
# Loss Pengujian: 0.7031
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.7550
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.7353
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 57.32%
# Loss Pelatihan: 0.6649
# Akurasi Pengujian: 64.61%
# Loss Pengujian: 0.6577
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 85.50%
# Loss Pelatihan: 0.3360
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4025
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3350
# Akurasi Pengujian: 78.90%
# Loss Pengujian: 0.4140
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3346
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4252
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3348
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4158
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3340
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4208
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4190
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4168
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3343
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4191
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4129
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 87.17%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.4157
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3421
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4017
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 84.52%
# Loss Pelatihan: 0.3667
# Akurasi Pengujian: 77.92%
# Loss Pengujian: 0.4314
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 81.17%
# Loss Pelatihan: 0.4751
# Akurasi Pengujian: 77.60%
# Loss Pengujian: 0.4893
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 64.71%
# Loss Pelatihan: 0.6280
# Akurasi Pengujian: 56.17%
# Loss Pengujian: 0.6513
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.6953
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.6814
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6819
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6953
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 85.08%
# Loss Pelatihan: 0.3409
# Akurasi Pengujian: 77.92%
# Loss Pengujian: 0.4548
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3419
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4532
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 80.47%
# Loss Pelatihan: 1.3280
# Akurasi Pengujian: 76.95%
# Loss Pengujian: 1.7275
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3350
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4150
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3367
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4164
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4163
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4171
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3342
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4149
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3341
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.4135
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4161
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4152
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3348
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4112
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 85.08%
# Loss Pelatihan: 0.3521
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.3940
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 81.31%
# Loss Pelatihan: 0.4555
# Akurasi Pengujian: 78.25%
# Loss Pengujian: 0.4574
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 72.38%
# Loss Pelatihan: 0.6203
# Akurasi Pengujian: 67.86%
# Loss Pengujian: 0.6290
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 49.09%
# Loss Pelatihan: 0.6888
# Akurasi Pengujian: 52.92%
# Loss Pengujian: 0.6915
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 79.78%
# Loss Pelatihan: 0.4433
# Akurasi Pengujian: 75.97%
# Loss Pengujian: 0.5195
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3384
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4284
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.05%
# Loss Pelatihan: 0.3633
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4329
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 85.22%
# Loss Pelatihan: 0.3544
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.4290
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3341
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4141
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3349
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4137
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 85.50%
# Loss Pelatihan: 0.3414
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4170
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3472
# Akurasi Pengujian: 81.49%
# Loss Pengujian: 0.4202
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 80.33%
# Loss Pelatihan: 0.3828
# Akurasi Pengujian: 76.62%
# Loss Pengujian: 0.4402
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 79.22%
# Loss Pelatihan: 0.4678
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4718
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 75.87%
# Loss Pelatihan: 0.5746
# Akurasi Pengujian: 72.08%
# Loss Pengujian: 0.5813
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 74.62%
# Loss Pelatihan: 0.5988
# Akurasi Pengujian: 72.73%
# Loss Pengujian: 0.6029
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 69.32%
# Loss Pelatihan: 0.6642
# Akurasi Pengujian: 68.51%
# Loss Pengujian: 0.6655
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 52.16%
# Loss Pelatihan: 0.7048
# Akurasi Pengujian: 48.05%
# Loss Pengujian: 0.7097
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.7419
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.7275
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 52.02%
# Loss Pelatihan: 0.6599
# Akurasi Pengujian: 55.19%
# Loss Pengujian: 0.6500
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3566
# Akurasi Pengujian: 81.49%
# Loss Pengujian: 0.4699
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3537
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4090
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3355
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4150
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3350
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4216
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3357
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4339
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3353
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4054
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3338
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4151
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.05%
# Loss Pelatihan: 0.3341
# Akurasi Pengujian: 78.90%
# Loss Pengujian: 0.4155
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3340
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.4122
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 85.63%
# Loss Pelatihan: 0.3507
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.4015
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 84.66%
# Loss Pelatihan: 0.3791
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.4069
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 80.20%
# Loss Pelatihan: 0.4835
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4778
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 79.50%
# Loss Pelatihan: 0.5952
# Akurasi Pengujian: 71.75%
# Loss Pengujian: 0.6090
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 54.53%
# Loss Pelatihan: 0.6723
# Akurasi Pengujian: 52.27%
# Loss Pengujian: 0.6820
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 53.97%
# Loss Pelatihan: 0.6930
# Akurasi Pengujian: 47.08%
# Loss Pengujian: 0.7021
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 44.77%
# Loss Pelatihan: 0.7194
# Akurasi Pengujian: 41.56%
# Loss Pengujian: 0.7235
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 85.91%
# Loss Pelatihan: 0.3498
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4286
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3506
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4049
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4178
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3353
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4274
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3343
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4226
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3340
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4145
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4124
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4133
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.4119
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4135
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 85.91%
# Loss Pelatihan: 0.3439
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.3986
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 85.50%
# Loss Pelatihan: 0.3549
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.4237
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 79.64%
# Loss Pelatihan: 0.4755
# Akurasi Pengujian: 73.70%
# Loss Pengujian: 0.4920
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 69.60%
# Loss Pelatihan: 0.6164
# Akurasi Pengujian: 67.21%
# Loss Pengujian: 0.6247
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 60.53%
# Loss Pelatihan: 0.6739
# Akurasi Pengujian: 57.14%
# Loss Pengujian: 0.6891
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.7579
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.7310
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3376
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4072
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 62.06%
# Loss Pelatihan: 0.8220
# Akurasi Pengujian: 69.16%
# Loss Pengujian: 0.7261
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3395
# Akurasi Pengujian: 81.49%
# Loss Pengujian: 0.4359
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3348
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4106
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3348
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4108
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3341
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4138
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4134
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4098
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4174
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4155
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4164
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3338
# Akurasi Pengujian: 78.25%
# Loss Pengujian: 0.4159
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 83.82%
# Loss Pelatihan: 0.3501
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.3965
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 79.92%
# Loss Pelatihan: 0.5043
# Akurasi Pengujian: 75.65%
# Loss Pengujian: 0.5276
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 77.27%
# Loss Pelatihan: 0.5485
# Akurasi Pengujian: 74.03%
# Loss Pengujian: 0.5603
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 71.13%
# Loss Pelatihan: 0.6530
# Akurasi Pengujian: 66.88%
# Loss Pengujian: 0.6585
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3359
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4127
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3352
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4259
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3389
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4103
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3352
# Akurasi Pengujian: 78.90%
# Loss Pengujian: 0.4150
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3365
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4157
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3345
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4039
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 87.59%
# Loss Pelatihan: 0.3417
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4156
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.19%
# Loss Pelatihan: 0.3439
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4185
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 84.52%
# Loss Pelatihan: 0.3619
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.3951
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 76.01%
# Loss Pelatihan: 0.5681
# Akurasi Pengujian: 75.00%
# Loss Pengujian: 0.5874
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 62.06%
# Loss Pelatihan: 0.6293
# Akurasi Pengujian: 64.29%
# Loss Pengujian: 0.6317
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6787
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.7046
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 74.34%
# Loss Pelatihan: 0.6364
# Akurasi Pengujian: 72.73%
# Loss Pengujian: 0.6328
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 56.49%
# Loss Pelatihan: 0.6880
# Akurasi Pengujian: 51.30%
# Loss Pengujian: 0.7052
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.7165
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.7059
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 52.30%
# Loss Pelatihan: 0.6969
# Akurasi Pengujian: 48.05%
# Loss Pengujian: 0.7092
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3494
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4456
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 83.96%
# Loss Pelatihan: 1.3398
# Akurasi Pengujian: 78.57%
# Loss Pengujian: 1.7923
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3345
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4205
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3557
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4173
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 87.17%
# Loss Pelatihan: 0.3361
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4180
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 87.45%
# Loss Pelatihan: 0.3346
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.4162
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4172
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3356
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4133
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3350
# Akurasi Pengujian: 81.49%
# Loss Pengujian: 0.4080
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 85.91%
# Loss Pelatihan: 0.3384
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4050
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 76.71%
# Loss Pelatihan: 0.4600
# Akurasi Pengujian: 75.32%
# Loss Pengujian: 0.4827
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 81.17%
# Loss Pelatihan: 0.4623
# Akurasi Pengujian: 78.90%
# Loss Pengujian: 0.4740
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 75.17%
# Loss Pelatihan: 0.5735
# Akurasi Pengujian: 71.43%
# Loss Pengujian: 0.5892
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 71.69%
# Loss Pelatihan: 0.6104
# Akurasi Pengujian: 72.40%
# Loss Pengujian: 0.6173
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 53.00%
# Loss Pelatihan: 0.7043
# Akurasi Pengujian: 47.73%
# Loss Pengujian: 0.7099
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.7044
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.6953
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 83.68%
# Loss Pelatihan: 0.3577
# Akurasi Pengujian: 78.90%
# Loss Pengujian: 0.4477
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 87.17%
# Loss Pelatihan: 0.3429
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4063
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3359
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4044
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 87.59%
# Loss Pelatihan: 0.3370
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4365
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3344
# Akurasi Pengujian: 78.90%
# Loss Pengujian: 0.4183
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3341
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4165
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4168
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4128
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4108
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3343
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4164
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3436
# Akurasi Pengujian: 81.49%
# Loss Pengujian: 0.4082
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 81.03%
# Loss Pelatihan: 0.3927
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4286
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 80.20%
# Loss Pelatihan: 0.5096
# Akurasi Pengujian: 77.60%
# Loss Pengujian: 0.5271
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 57.88%
# Loss Pelatihan: 0.6281
# Akurasi Pengujian: 62.99%
# Loss Pengujian: 0.6142
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 79.78%
# Loss Pelatihan: 0.6362
# Akurasi Pengujian: 77.60%
# Loss Pengujian: 0.6378
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 67.09%
# Loss Pelatihan: 0.6456
# Akurasi Pengujian: 61.36%
# Loss Pengujian: 0.6605
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3369
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4091
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3346
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4157
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3381
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4116
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3379
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4100
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3344
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.4122
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3340
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4163
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4108
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3345
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4281
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4183
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4175
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4163
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 86.05%
# Loss Pelatihan: 0.3367
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.3917
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 82.85%
# Loss Pelatihan: 0.3696
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4085
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 82.15%
# Loss Pelatihan: 0.4526
# Akurasi Pengujian: 81.49%
# Loss Pengujian: 0.4563
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.7098
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.6794
#
# Melatih dengan 3 lapisan tersembunyi, 8 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 74.76%
# Loss Pelatihan: 0.6096
# Akurasi Pengujian: 72.08%
# Loss Pengujian: 0.6181
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3461
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4153
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3360
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4158
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 74.90%
# Loss Pelatihan: 0.5439
# Akurasi Pengujian: 74.68%
# Loss Pengujian: 0.5698
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 84.38%
# Loss Pelatihan: 0.7758
# Akurasi Pengujian: 76.62%
# Loss Pengujian: 1.1370
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3348
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4167
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.19%
# Loss Pelatihan: 0.3348
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4113
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3349
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4238
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 83.96%
# Loss Pelatihan: 0.3425
# Akurasi Pengujian: 78.25%
# Loss Pengujian: 0.4286
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 85.91%
# Loss Pelatihan: 0.3419
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.3867
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 84.80%
# Loss Pelatihan: 0.3681
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4109
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 71.97%
# Loss Pelatihan: 0.5910
# Akurasi Pengujian: 72.73%
# Loss Pengujian: 0.5776
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 73.22%
# Loss Pelatihan: 0.6068
# Akurasi Pengujian: 72.08%
# Loss Pengujian: 0.6197
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 80.33%
# Loss Pelatihan: 0.5561
# Akurasi Pengujian: 75.00%
# Loss Pengujian: 0.5657
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 72.80%
# Loss Pelatihan: 0.6121
# Akurasi Pengujian: 72.08%
# Loss Pengujian: 0.6158
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 44.35%
# Loss Pelatihan: 0.7065
# Akurasi Pengujian: 45.45%
# Loss Pengujian: 0.7021
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 54.81%
# Loss Pelatihan: 0.6878
# Akurasi Pengujian: 55.19%
# Loss Pengujian: 0.6862
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3406
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.4495
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3603
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4949
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3346
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4174
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.05%
# Loss Pelatihan: 0.3550
# Akurasi Pengujian: 82.47%
# Loss Pengujian: 0.4320
#
# ...
# Loss Pengujian: 0.4176
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3341
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4154
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4140
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4155
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3344
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4095
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 85.77%
# Loss Pelatihan: 0.3392
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.3919
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3699
# Akurasi Pengujian: 84.09%
# Loss Pengujian: 0.4004
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 85.36%
# Loss Pelatihan: 0.4042
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4348
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 84.94%
# Loss Pelatihan: 0.3510
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4465
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 60.81%
# Loss Pelatihan: 1.2371
# Akurasi Pengujian: 57.47%
# Loss Pengujian: 1.2713
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 78.80%
# Loss Pelatihan: 2.3106
# Akurasi Pengujian: 76.62%
# Loss Pengujian: 2.6035
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 75.03%
# Loss Pelatihan: 0.5533
# Akurasi Pengujian: 73.70%
# Loss Pengujian: 0.5381
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3373
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4144
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.19%
# Loss Pelatihan: 0.3347
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4193
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3354
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4087
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 85.63%
# Loss Pelatihan: 0.3400
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4117
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 85.91%
# Loss Pelatihan: 0.3348
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4058
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3422
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.3982
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 84.80%
# Loss Pelatihan: 0.3769
# Akurasi Pengujian: 82.47%
# Loss Pengujian: 0.4057
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 76.15%
# Loss Pelatihan: 0.5105
# Akurasi Pengujian: 76.30%
# Loss Pengujian: 0.5213
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 80.89%
# Loss Pelatihan: 0.5760
# Akurasi Pengujian: 77.60%
# Loss Pengujian: 0.5813
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 64.85%
# Loss Pelatihan: 0.6523
# Akurasi Pengujian: 64.94%
# Loss Pengujian: 0.6561
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 71.27%
# Loss Pelatihan: 0.6463
# Akurasi Pengujian: 67.21%
# Loss Pengujian: 0.6518
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 10 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 70.71%
# Loss Pelatihan: 0.6500
# Akurasi Pengujian: 66.56%
# Loss Pengujian: 0.6532
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3420
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4220
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 84.52%
# Loss Pelatihan: 0.3530
# Akurasi Pengujian: 78.90%
# Loss Pengujian: 0.4106
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 85.77%
# Loss Pelatihan: 0.3565
# Akurasi Pengujian: 82.47%
# Loss Pengujian: 0.4093
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 77.13%
# Loss Pelatihan: 4.1958
# Akurasi Pengujian: 70.45%
# Loss Pengujian: 7.4643
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.19%
# Loss Pelatihan: 0.3360
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4165
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 87.17%
# Loss Pelatihan: 0.3353
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4073
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3344
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4154
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3353
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4067
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3364
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4126
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4143
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3341
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4156
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3403
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4056
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 82.43%
# Loss Pelatihan: 0.3925
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4168
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 77.41%
# Loss Pelatihan: 0.5306
# Akurasi Pengujian: 75.32%
# Loss Pengujian: 0.5368
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 75.45%
# Loss Pelatihan: 0.5638
# Akurasi Pengujian: 72.73%
# Loss Pengujian: 0.5618
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 68.06%
# Loss Pelatihan: 0.6350
# Akurasi Pengujian: 68.83%
# Loss Pengujian: 0.6286
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3405
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.4052
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3342
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4166
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3377
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.4068
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3388
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.4364
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 85.50%
# Loss Pelatihan: 0.3388
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.3985
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3346
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4085
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3342
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4090
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3367
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4233
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4182
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3338
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4213
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4167
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.4095
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 85.63%
# Loss Pelatihan: 0.3388
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.3992
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 83.12%
# Loss Pelatihan: 0.3873
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4137
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 79.50%
# Loss Pelatihan: 0.5049
# Akurasi Pengujian: 77.27%
# Loss Pengujian: 0.5160
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 82.57%
# Loss Pelatihan: 0.5715
# Akurasi Pengujian: 77.92%
# Loss Pengujian: 0.5811
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 83.26%
# Loss Pelatihan: 0.6569
# Akurasi Pengujian: 76.30%
# Loss Pengujian: 0.9653
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3351
# Akurasi Pengujian: 78.25%
# Loss Pengujian: 0.4243
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3340
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4139
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3341
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4144
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3353
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4116
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3340
# Akurasi Pengujian: 79.22%
# Loss Pengujian: 0.4189
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3347
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4212
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3343
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4203
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3341
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4103
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3337
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4165
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3336
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4157
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3339
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4144
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3340
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.4073
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 86.61%
# Loss Pelatihan: 0.3345
# Akurasi Pengujian: 81.49%
# Loss Pengujian: 0.4064
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 84.66%
# Loss Pelatihan: 0.3646
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4134
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 81.59%
# Loss Pelatihan: 0.4468
# Akurasi Pengujian: 76.95%
# Loss Pengujian: 0.4762

# %%
# Menampilkan best dan worst hyperparameter berdasarkan akurasi
print("\nBest Hyperparameter Configuration:")
print(f"Hidden Layers: {best_result['Hyperparameters']['Hidden Layers']}")
print(f"Hidden Neurons: {best_result['Hyperparameters']['Hidden Neurons']}")
print(f"Activation Function: {best_result['Hyperparameters']['Activation Function']}")
print(f"Epochs: {best_result['Hyperparameters']['Epochs']}")
print(f"Learning Rate: {best_result['Hyperparameters']['Learning Rate']}")
print(f"Batch Size: {best_result['Hyperparameters']['Batch Size']}")
print(f"Test Accuracy: {best_result['Test Accuracy'] * 100:.2f}%")
# Out:
# Best Hyperparameter Configuration:
# Hidden Layers: 3
# Hidden Neurons: 32
# Activation Function: Softmax
# Epochs: 100
# Learning Rate: 0.0001
# Batch Size: 256
# Test Accuracy: 84.09%

# %%
# Menampilkan hyperparameter terburuk berdasarkan akurasi terendah
print("\nWorst Hyperparameter Configuration:")
print(f"Hidden Layers: {worst_result['Hyperparameters']['Hidden Layers']}")
print(f"Hidden Neurons: {worst_result['Hyperparameters']['Hidden Neurons']}")
print(f"Activation Function: {worst_result['Hyperparameters']['Activation Function']}")
print(f"Epochs: {worst_result['Hyperparameters']['Epochs']}")
print(f"Learning Rate: {worst_result['Hyperparameters']['Learning Rate']}")
print(f"Batch Size: {worst_result['Hyperparameters']['Batch Size']}")
print(f"Test Accuracy: {worst_result['Test Accuracy'] * 100:.2f}%")
# Out:
# Worst Hyperparameter Configuration:
# Hidden Layers: 2
# Hidden Neurons: 8
# Activation Function: linear
# Epochs: 10
# Learning Rate: 0.0001
# Batch Size: 256
# Test Accuracy: 32.14%
